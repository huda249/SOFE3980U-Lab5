# %% [markdown]
# # Great Expectations Task

# %% [markdown]
# ## 1. Install Great Expectations Library

# %%
# !pip install great_expectations
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 11.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##2. Import Necessary Libraries

# %%
import pandas as pd
import great_expectations as gx
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ##3. Load Labels.csv

# %% [markdown]
# Download and upload the [Labels.csv](https://github.com/zubxxr/SOFE3980U-Lab5/blob/main/Labels.csv) into this notebook, and then load the file.

# %%
# Write code here
import pandas as pd

df = pd.read_csv("Labels.csv")
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ##4. Preview the Dataset

# %%
df.head()
# Out:
#     Timestamp  Car1_Location_X  Car1_Location_Y  Car1_Location_Z  \
# 0  1736796157       -51.402977              143         0.596902
# 1  1736796167       -53.819637              143         0.596902
# 2  1736796178       -50.239144              143         0.596902
# 3  1736796188       -53.707220              143         0.596902
# 4  1736796198       -52.053721              143         0.596902
#
#    Car2_Location_X  Car2_Location_Y  Car2_Location_Z Occluded_Image_view  \
# 0       -59.320270              140         0.596902           A_001.png
# 1       -59.196568              140         0.596902           A_002.png
# 2       -56.744479              140         0.596902           A_003.png
# 3       -57.309380              140         0.596902           A_004.png
# 4       -59.545897              140         0.596902           A_005.png
#
#   Occluding_Car_view Ground_Truth_View  pedestrianLocationX_TopLeft  \
# ...

# %% [markdown]
# ##5. Set Up Great Expectations Context and Data Source

# %%
# Write code here
import great_expectations as ge

context = ge.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")
# Out:
# INFO:great_expectations.data_context.types.base:Created temporary directory '/tmp/tmpd8_8vjf7' for ephemeral docs site

# %% [markdown]
# ##6. Define and Create a Data Batch

# %%
# Write code here
batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": df})
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ##7. Define Three Expectations for Column Values

# %% [markdown]
# Using this [link](https://greatexpectations.io/expectations/), choose three expectation functions and apply them to the labels dataset in a relevant manner.
#
# You should replace the 'ExpectColumnValuesToBeBetween' function with other functions you select from the link.
#
# You can also check the format/parameters required of each function when you click "See more" on the function.

# %%
## Original Function
expectation = ge.expectations.ExpectColumnValuesToBeBetween(
    column="column", min_value=0, max_value=20
)

## Example Function

## This function only requires a column parameter, and not a max or min value
expectation = ge.expectations.ExpectColumnValuesToBeUnique(
    column="column"
)

# %% [markdown]
# ### Expectation 1

# %%
# Write code here
expectation1 = ge.expectations.ExpectColumnValuesToNotBeNull(
    column="age"
)

# %% [markdown]
# ### Validate Data Against Expectation 1

# %%
# Write code here
vr1 = batch.validate(expectation1)
print(vr1)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": false,
#   "expectation_config": {
#     "type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "age",
#       "batch_id": "pandas-pd dataframe asset"
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {},
#   "meta": {},
#   "exception_info": {
#     "MetricConfigurationID(metric_name='column_values.nonnull.condition', metric_domain_kwargs_id='0f70984eed9bd39041006694baf43b2e', metric_value_kwargs_id=())": {
# ...

# %% [markdown]
# ### Expectation 2

# %%
# Write code here
expectation2 = ge.expectations.ExpectColumnValuesToBeInSet(
    column="income",
    value_set=["<=50K", ">50K"]
)

# %% [markdown]
# ### Validate Data Against Expectation 2

# %%
# Write code here
vr2 = batch.validate(expectation2)
print(vr2)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# {
#   "success": false,
#   "expectation_config": {
#     "type": "expect_column_values_to_be_in_set",
#     "kwargs": {
#       "column": "income",
#       "value_set": [
#         "<=50K",
#         ">50K"
#       ],
#       "batch_id": "pandas-pd dataframe asset"
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {},
#   "meta": {},
#   "exception_info": {
#     "MetricConfigurationID(metric_name='column_values.in_set.condition', metric_domain_kwargs_id='2c7623762a54ee8f03aafa5455dac903', metric_value_kwargs_id=\"value_set=['<=50K', '>50K']\")": {
# ...

# %% [markdown]
# ### Expectation 3

# %%
# Write code here
expectation3 = ge.expectations.ExpectColumnToExist(
    column="education"
)

# %% [markdown]
# ### Validate Data Against Expectation 3

# %%
# Write code here
vr3 = batch.validate(expectation3)
print(vr3)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "success": false,
#   "expectation_config": {
#     "type": "expect_column_to_exist",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "education"
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {},
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
# ...
